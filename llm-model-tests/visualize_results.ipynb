# %% [markdown]
# # Alpamayo Results Visualizer
#
# Run the cell below to verify the results of the Alpamayo model interactively.

# %%
from notebook_visualizer import NotebookVisualizer

# Update the filename if you have a different results file
results_file = 'route_1_seg_00_results.json'

try:
    viz = NotebookVisualizer(results_file)
except Exception as e:
    print(f"Could not load visualizer: {e}")
    print(f"Make sure '{results_file}' exists.")
